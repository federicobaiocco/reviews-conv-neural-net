# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
class emt_peru_crawler():
    def __init__(self, base_url):
        if type(base_url) != str:
            raise("base_url must be str type.")
        if "elmejortrato.com.pe" not in base_url:
            raise("base_url must contain elmejortrato.com.pe")
        self._ratings = []
        self._base_url = base_url
    
    def crawl(self):
        '''
        Inicia todo el proceso.
        Cuando se inicializa la clase, se debe inicializar con una base_url desde la cual
        se empezará el proceso. Esta url_base tiene que contener un listado de posts padres.
        '''
        r = requests.get(self._base_url) 
        soup = BeautifulSoup(r.content, 'html5lib') 
        topics_container = soup.find('section', attrs={'class':'results'})
        for topic in topics_container.findAll('a'):
            print("Crawling parent post "+str(topic['href']))
            parent_post_soup = self.get_soup(topic['href'])
            self.get_post_ratings(parent_post_soup)
            self.get_children_posts_ratings(parent_post_soup)
            
    def get_soup(self, url):
        '''
        Devuelve el contenido html de una url específica.
        '''
        if "https://elmejortrato.com.pe" not in url:
            url = "https://elmejortrato.com.pe" + url
        r = requests.get(url)
        soup = BeautifulSoup(r.content, 'html5lib')
        return soup
    
    def get_post_ratings(self, post_soup):
        '''
        Recibe el html de un post y busca todos los ratings que haya en ese post.
        Retorna un array con el contenido de todos los ratings.
        '''
        ratings_container = post_soup.find('section', attrs = {'id':'califications'}) 
        ratings = []
        for row in ratings_container.findAll('div', attrs = {'class':'cal'}): 
            rating = {
                'text': row.p.text,
                'state': 1 # 1=Approved
            } 
            self._ratings.append(rating)
    
    def get_children_posts_ratings(self, parent_post_soup):
        '''
        Cada post, tiene al fondo una sección de articulos relacionados o "hijos".
        En este método, se busca esa sección y se va a cada uno de los posts que estan en esa
        sección a buscar sus ratings.
        '''
        related_section = parent_post_soup.find('div',attrs={'id':'relations'})
        if related_section is not None:
            children_url = ["https://elmejortrato.com.pe" + url['href'] for url in related_section.findAll('a')]
            for url in children_url:
                print("Crawling child post "+str(url))
                child_post_soup = self.get_soup(url)
                self.get_post_ratings(child_post_soup)
            
    def export_to_csv(self, filename):
        if len(self._ratings) > 0:
            df = pd.DataFrame(data=self._ratings)
            df.to_csv(filename, index=False,encoding='utf-8')
        else:
            raise("Ratings size must be greater than 0.")

# %%
# %%time
seguros_por_aseguradora = emt_peru_crawler("https://www.elmejortrato.com.pe/seguros/seguros-por-aseguradora")
seguros_por_aseguradora.crawl()
seguros_por_aseguradora.export_to_csv('./data/seguros-por-aseguradora.csv')
# Out:
# Crawling parent post /seguros/hdi-seguros-vehiculares-en-peru
# Crawling child post https://elmejortrato.com.pe/seguros/hdi-seguros-vehiculares-en-peru/direccion-y-telefono-de-oficinas-de-hdi-seguros-en-peru
# Crawling parent post /seguros/seguros-vehiculares-mapfre
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-mapfre/seguros-mapfre-para-autos-en-cusco
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-mapfre/seguros-mapfre-en-miraflores
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-mapfre/seguros-mapfre-en-chiclayo
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-mapfre/seguros-mapfre-en-tacna
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-mapfre/seguros-mapfre-en-trujillo-peru
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-mapfre/telefonos-de-seguros-mapfre
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-mapfre/seguro-de-auto-mapfre-para-lima
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-mapfre/seguros-vehiculares-mapfre-en-puno
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-mapfre/seguros-mapfre-para-arequipa
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-mapfre/seguros-mapfre-para-cajamarca
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-mapfre/seguros-mapfre-en-piura
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-mapfre/mapfre-seguros-soat
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-mapfre/seguros-mapfre-en-junin
# Crawling parent post /seguros/seguros-vehiculares-pacifico
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-en-ica
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-para-cusco
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/pacifico-seguros-para-miraflores
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/pacifico-seguros-para-juliaca
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-en-arequipa
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-en-huaraz
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/pacifico-seguros-para-junin
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-en-huanuco
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-soat-de-pacifico-seguros
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-para-talara
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-en-puno
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/pacifico-seguros-en-iquitos
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-para-tacna
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-para-piura
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-en-jaen
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-en-lima
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/pacifico-seguro-que-cubre
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/pacifico-seguros-para-huancayo
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-o-rimac-cual-es-mejor
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/pacifico-seguro-todo-riesgo-que-cubre
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/pacifico-seguros-en-chiclayo
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-en-trujillo
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/seguros-pacifico-para-ilo
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-pacifico/oficinas-sucursales-telefono-y-agencias-de-seguros-pacifico
# Crawling parent post /seguros/seguros-vehiculares-falabella
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-falabella/telefono-de-seguros-falabella
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-falabella/seguros-falabella-en-lima
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-falabella/seguros-de-autos-falabella-para-chiclayo
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-falabella/seguros-falabella-en-arequipa
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-falabella/seguros-la-positiva-en-cusco
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-falabella/seguros-falabella-soat
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-falabella/corredores-de-seguros-falabella
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-falabella/sucursales-de-seguros-falabella
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-falabella/seguros-falabella-vehiculares-en-trujillo
# Crawling parent post /seguros/seguros-vehiculares-ripley
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-ripley/ripley-seguros-soat
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-ripley/promocion-de-seguro-vehicular-ripley-en-peru
# Crawling parent post /seguros/seguro-vehicular-interseguro
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-vehicular-interseguro/beneficios-de-seguro-vehicular-interseguro
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-vehicular-interseguro/seguro-vehicular-interseguro-en-ica
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-vehicular-interseguro/seguro-vehicular-interseguro-oficinas-direccion-y-telefono
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-vehicular-interseguro/soat-en-interseguro
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-vehicular-interseguro/seguro-vehicular-interseguro-en-trujillo
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-vehicular-interseguro/seguro-vehicular-y-soat-de-interseguro-en-lima
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-vehicular-interseguro/seguros-para-auto-interseguro-en-piura
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-vehicular-interseguro/seguro-para-auto-de-interseguro-en-arequipa
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-vehicular-interseguro/seguro-vehicular-interseguro-en-huancayo
# Crawling parent post /seguros/seguros-vehiculares-rimac
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/rimac-seguros-para-tarapoto
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/rimac-seguros-para-san-isidro
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/rimac-seguros-para-trujillo
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/rimac-seguros-para-pucallpa
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/rimac-seguros-en-ayacucho
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/seguros-rimac-para-san-juan-de-lurigancho
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/rimac-seguros-en-huaraz
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/oficinas-telefonos-y-sucursales-de-rimac-seguros
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/seguros-rimac-en-puno
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/seguros-rimac-en-junin
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/rimac-seguros-para-huanuco
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/rimac-seguros-en-tacna
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/seguros-rimac-en-chiclayo
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/seguros-rimac-en-huancayo
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/rimac-seguros-en-iquitos
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/seguros-rimac-en-juliaca
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/rimac-seguros-para-miraflores
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/seguros-rimac-en-lima
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/seguros-rimac-en-piura
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/seguros-rimac-que-cubre
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/rimac-seguros-para-cusco
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/seguros-rimac-en-ica
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/rimac-seguros-en-arequipa
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/cual-es-mejor-seguro-vehicular-rimac-o-pacifico
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-rimac/seguros-soat-de-rimac
# Crawling parent post /seguros/seguros-vehiculares-la-positiva
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-para-huanuco
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-para-taxi
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-para-piura
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-en-ayacucho
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-para-cajamarca
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-en-miraflores
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-soat-de-la-positiva
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-en-tacna
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-en-ica
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-para-san-juan-de-lurigancho
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-en-lima
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-en-arequipa
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-en-puno
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-para-juliaca
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-en-tumbes
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/agencias-de-seguros-la-positiva
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-en-chiclayo
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-en-huaraz
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-en-chimbote
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/la-positiva-seguros-para-lambayeque
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-para-talara
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/telefonos-de-los-seguros-la-positiva
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-en-los-olivos
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/beneficios-de-la-positiva-seguros
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/direccion-para-seguros-la-positiva
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-la-positiva/seguros-la-positiva-en-trujillo
# Crawling parent post /seguros/seguro-vehicular-bbva
# Crawling parent post /seguros/seguros-vehicular-scotiabank-peru
# Crawling parent post /seguros/seguro-vehicular-interbank
# Crawling parent post /seguros/soat-vehicular-bcp
# Wall time: 1min 53s

# %%
# %%time
seguros_por_provincia = emt_peru_crawler("https://www.elmejortrato.com.pe/seguros/seguros-por-provincia")
seguros_por_provincia.crawl()
seguros_por_provincia.export_to_csv('./data/seguros-por-provincia.csv')
# Out:
# Crawling parent post /seguros/seguro-de-auto-en-moquegua
# Crawling parent post /seguros/seguro-de-auto-en-arequipa
# Crawling parent post /seguros/seguro-de-auto-en-huaral
# Crawling parent post /seguros/seguro-vehicular-en-puerto-maldonado
# Crawling parent post /seguros/seguro-para-auto-en-cusco
# Crawling parent post /seguros/seguro-vehicular-en-huancayo
# Crawling parent post /seguros/seguro-para-auto-en-huanuco
# Crawling parent post /seguros/seguro-para-auto-en-lima
# Crawling parent post /seguros/seguro-vehicular-en-tingo-maria
# Crawling parent post /seguros/seguro-de-auto-en-paita
# Crawling parent post /seguros/seguro-vehicular-en-callao
# Crawling parent post /seguros/seguro-para-auto-en-san-martin
# Crawling parent post /seguros/seguro-vehicular-en-juliaca
# Crawling parent post /seguros/seguro-de-auto-en-tacna
# Crawling parent post /seguros/seguro-para-auto-en-cajamarca
# Crawling parent post /seguros/seguro-de-auto-en-jaen
# Crawling parent post /seguros/seguro-de-auto-en-chimbote
# Crawling parent post /seguros/seguro-de-auto-en-iquitos
# Crawling parent post /seguros/seguro-para-auto-en-chiclayo
# Crawling parent post /seguros/seguro-vehicular-en-tarapoto
# Crawling parent post /seguros/seguro-para-auto-en-puno
# Crawling parent post /seguros/seguro-vehicular-en-barranca
# Crawling parent post /seguros/seguro-de-auto-en-abancay
# Crawling parent post /seguros/seguro-vehicular-en-san-vicente-de-canete
# Crawling parent post /seguros/seguro-para-auto-en-huacho
# Crawling parent post /seguros/seguro-vehicular-en-moyobamba
# Crawling parent post /seguros/seguro-vehicular-en-trujillo
# Crawling parent post /seguros/seguro-vehicular-en-piura
# Crawling parent post /seguros/seguro-vehicular-en-talara
# Crawling parent post /seguros/seguro-vehicular-en-coronel-portillo
# Crawling parent post /seguros/seguro-para-auto-en-tumbes
# Crawling parent post /seguros/seguro-de-auto-en-ilo
# Crawling parent post /seguros/seguro-de-auto-en-pisco
# Crawling parent post /seguros/seguro-vehicular-en-ica
# Crawling parent post /seguros/seguro-vehicular-en-ayacucho
# Crawling parent post /seguros/seguro-para-auto-en-sullana
# Crawling parent post /seguros/seguro-de-auto-en-lambayeque
# Crawling parent post /seguros/seguro-de-auto-en-pucallpa
# Wall time: 35.3 s

# %%
# %%time
seguros_por_auto = emt_peru_crawler("https://www.elmejortrato.com.pe/seguros/seguros-por-auto")
seguros_por_auto.crawl()
seguros_por_auto.export_to_csv('./data/seguros-por-auto.csv')
# Out:
# Crawling parent post /seguros/donde-contratar-seguro-vehicular-para-toyota
# Crawling child post https://elmejortrato.com.pe/seguros/donde-contratar-seguro-vehicular-para-toyota/como-contratar-un-seguro-vehicular-para-toyota-corolla
# Crawling child post https://elmejortrato.com.pe/seguros/donde-contratar-seguro-vehicular-para-toyota/que-seguro-de-auto-conviene-para-toyota-hilux
# Crawling child post https://elmejortrato.com.pe/seguros/donde-contratar-seguro-vehicular-para-toyota/donde-contratar-seguro-vehicular-para-toyota-yaris
# Crawling parent post /seguros/como-contratar-un-seguro-vehicular-para-volkswagen
# Crawling parent post /seguros/que-seguro-de-auto-conviene-para-renault
# Crawling parent post /seguros/que-seguro-de-auto-conviene-para-kia
# Crawling child post https://elmejortrato.com.pe/seguros/que-seguro-de-auto-conviene-para-kia/seguros-vehiculares-para-kia-picanto
# Crawling child post https://elmejortrato.com.pe/seguros/que-seguro-de-auto-conviene-para-kia/seguros-para-autos-chevrolet-sail
# Crawling child post https://elmejortrato.com.pe/seguros/que-seguro-de-auto-conviene-para-kia/mejores-seguros-de-auto-para-kia-sportage
# Crawling child post https://elmejortrato.com.pe/seguros/que-seguro-de-auto-conviene-para-kia/como-contratar-un-seguro-vehicular-para-kia-rio
# Crawling parent post /seguros/seguros-para-autos-mahindra
# Crawling parent post /seguros/como-contratar-un-seguro-vehicular-para-hyundai
# Crawling child post https://elmejortrato.com.pe/seguros/como-contratar-un-seguro-vehicular-para-hyundai/que-seguro-de-auto-conviene-para-hyundai-i10
# Crawling child post https://elmejortrato.com.pe/seguros/como-contratar-un-seguro-vehicular-para-hyundai/donde-contratar-seguro-vehicular-para-hyundai-accent
# Crawling child post https://elmejortrato.com.pe/seguros/como-contratar-un-seguro-vehicular-para-hyundai/donde-contratar-seguro-vehicular-para-hyundai-tucson
# Crawling child post https://elmejortrato.com.pe/seguros/como-contratar-un-seguro-vehicular-para-hyundai/seguros-vehiculares-para-hyundai-elantra
# Crawling parent post /seguros/seguros-vehiculares-para-chevrolet
# Crawling child post https://elmejortrato.com.pe/seguros/seguros-vehiculares-para-chevrolet/seguros-vehiculares-para-chevrolet-spark
# Crawling parent post /seguros/mejores-seguros-de-auto-para-mitsubishi
# Crawling parent post /seguros/seguros-para-autos-suzuki
# Crawling parent post /seguros/donde-contratar-seguro-vehicular-para-mazda
# Crawling parent post /seguros/seguros-vehiculares-para-honda
# Crawling parent post /seguros/seguros-vehiculares-para-great-wall
# Crawling parent post /seguros/mejores-seguros-de-auto-para-nissan
# Crawling child post https://elmejortrato.com.pe/seguros/mejores-seguros-de-auto-para-nissan/mejores-seguros-de-auto-para-nissan-sentra
# Crawling parent post /seguros/seguros-para-autos-ford
# Wall time: 25.4 s

# %%
# %%time
seguros_por_tipo = emt_peru_crawler("https://www.elmejortrato.com.pe/seguros/seguros-por-tipo")
seguros_por_tipo.crawl()
seguros_por_tipo.export_to_csv('./data/seguros-por-tipo.csv')
# Out:
# Crawling parent post /seguros/seguro-vehicular-soat-peru
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-vehicular-soat-peru/seguro-vehicular-afocat
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-vehicular-soat-peru/soat-para-minivan-particular
# Crawling parent post /seguros/impuesto-vehicular-peru
# Crawling parent post /seguros/seguro-para-vehiculos
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-para-vehiculos/seguro-vehicular-para-camiones
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-para-vehiculos/que-cubre-el-seguro-vehicular
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-para-vehiculos/seguro-simple-auto
# Crawling child post https://elmejortrato.com.pe/seguros/seguro-para-vehiculos/seguros-vehiculos-transporte-pasajeros
# Wall time: 8.79 s

# %%
por_aseguradora_df = pd.read_csv('./data/seguros-por-aseguradora.csv')
por_auto_df = pd.read_csv('./data/seguros-por-auto.csv')
por_provincia_df = pd.read_csv('./data/seguros-por-provincia.csv')
por_tipo_df = pd.read_csv('./data/seguros-por-tipo.csv')
aprobados = pd.read_csv('./data/aprobados.csv')
approved_df = pd.concat([por_aseguradora_df,por_auto_df,por_provincia_df,por_tipo_df, aprobados])
approved_df.to_csv("./data/all_approved.csv", index=False)
